# %%
from lightgbm import LGBMRegressor
import lightgbm
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.preprocessing import FunctionTransformer
from sklearn.metrics import accuracy_score, f1_score, mean_squared_error
from sklearn.linear_model import Ridge, LinearRegression
import time
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import os
from bayes_opt import BayesianOptimization
import pickle
from bayes_opt.logger import JSONLogger
from bayes_opt.event import Events
from bayes_opt.util import load_logs
import json
from scipy.stats import pearsonr
import warnings
import seaborn as sns
warnings.filterwarnings('ignore')

# %%
path_train = "data/train_data.csv"
path_test = "data/test_data.csv"
target_ = "contest-tmp2m-14d__tmp2m"

# %%
df_train = pd.read_csv(path_train)
df_test = pd.read_csv(path_test)

date_col = "startdate"

df_train[date_col] = pd.to_datetime(df_train[date_col])
df_test[date_col] = pd.to_datetime(df_test[date_col])

# %%
list_new_col = []

# %%
drop_col = pd.read_csv("data/correlations_with_target_greater_0.7.csv")
drop_col = drop_col["col"].values
drop_col = [each for each in drop_col if "contest" not in each and "wind" not in each]

bin_col = ['nmme-tmp2m-34w__nmmemean', 'nmme-tmp2m-56w__nmmemean', 'nmme0-tmp2m-34w__nmme0mean', 'nmme0mean']

def bin_feature_tpm2m(x):
    if x < -5:
        return 'A'
    elif x < 0:
        return 'B'
    elif x < 5:
        return 'C'
    elif x < 10:
        return 'D'
    elif x < 15:
        return 'E'
    elif x < 20:
        return 'F'
    elif x < 25:
        return 'G'
    else:
        return 'H'

# %%
for each in bin_col:
    df_train[each + "_bin"] = np.vectorize(bin_feature_tpm2m)(df_train[each])
    df_test[each + "_bin"] = np.vectorize(bin_feature_tpm2m)(df_test[each])
    list_new_col.append(each + "_bin")

# %%
col = [each for each in df_train.columns if "contest" in each and each != target_]
def get_idx(lat, lon):
    return str(round(lat, 4)) + "_" + str(round(lon, 4))
df_train['idx'] = np.vectorize(get_idx)(df_train['lat'], df_train['lon'])
df_test['idx'] = np.vectorize(get_idx)(df_test['lat'], df_test['lon'])

# %%
for each in col:
    df_train[each + "_lag_1"] = df_train.groupby("idx")[each].shift(1).bfill()
    df_test[each + "_lag_1"] = df_test.groupby("idx")[each].shift(1).bfill()
    df_train[each + "_lag_2"] = df_train.groupby("idx")[each].shift(2).bfill()
    df_test[each + "_lag_2"] = df_test.groupby("idx")[each].shift(2).bfill()
    list_new_col.append(each + "_lag_1")
    list_new_col.append(each + "_lag_2")
    # df_train[each + "_shift_1"] = df_train.groupby("idx")[each].shift(-1).ffill()
    # df_test[each + "_shitf_1"] = df_test.groupby("idx")[each].shift(-1).ffill()

# %%
col_test = [each for each in df_train.columns if "contest" not in each and ("wind" in each or "sst" in each)]
col_drift = ["wind-vwnd-250-2010-2", "wind-vwnd-250-2010-16", "wind-vwnd-250-2010-19", "wind-uwnd-250-2010-9", "wind-uwnd-250-2010-11",
             "wind-uwnd-250-2010-17", "wind-hgt-850-2010-2", "wind-hgt-850-2010-5", "wind-hgt-850-2010-7", "sst-2010-2", "sst-2010-10",
             "wind-hgt-500-2010-5", "wind-hgt-500-2010-7", "wind-hgt-500-2010-8", "wind-uwnd-925-2010-2", "wind-uwnd-925-2010-7",
             "wind-uwnd-925-2010-20"]
dict_col_drift = {each:True for each in col_drift}

for each in col_test:
    if each in dict_col_drift:
        continue
    df_train[each + "_lag_1"] = df_train.groupby("idx")[each].shift(1).bfill()
    df_test[each + "_lag_1"] = df_test.groupby("idx")[each].shift(1).bfill()
    df_train[each + "_diff"] = df_train.groupby("idx")[each].diff().bfill()
    df_test[each + "_diff"] = df_test.groupby("idx")[each].diff().bfill()
    list_new_col.append(each + "_diff")
    list_new_col.append(each + "_lag_1")

# %%
def create_mean_group(df, cols_group, cols_mean, col_date="startdate"):
    list_new_col = []
    df[col_date] = df[col_date].astype("str")
    for col_mean in cols_mean:
        for col_group in cols_group:
            new_col = col_mean + "_{}".format(col_group) + "_mean"
            dict_map = df.groupby([col_group, col_date])[col_mean].mean().to_dict()
            # print(dict_map)
            def map_dict(gr, date):
                return dict_map[gr, date]
            
            df[new_col] = np.vectorize(map_dict)(df[col_group], df[col_date])
            list_new_col.append(new_col)
            
    df[col_date] = pd.to_datetime(df[col_date])
    return df, list_new_col

cols_group = ["lat", "lon", "climateregions__climateregion"]
df_train, list_col = create_mean_group(df_train, cols_group, col)
df_test, _ = create_mean_group(df_test, cols_group, col)
list_new_col = [*list_new_col, *list_col]

# %%
def get_name_cols(suffix='', cols=[]):
    name_cols = [col + f'{suffix}' for col in cols if col != 'contest-tmp2m-14d__tmp2m']

    return name_cols

def feature_engineer(df, cols):

    
    # mean_contest_cols = df.groupby(['idx', 'month', 'year'])[cols].transform(lambda x: x.mean()) \
    #     .rename(columns=dict(zip(cols, get_name_cols('_mean', cols))))
    # std_contest_cols = df.groupby(['idx', 'month', 'year'])[cols].transform(lambda x: x.std()) \
    #     .rename(columns=dict(zip(cols, get_name_cols('_std', cols))))
    rolling_mean_contest_cols = df.groupby('idx')[cols].transform(lambda x: x.rolling(window=3, min_periods=2).mean()) \
        .rename(columns=dict(zip(cols, get_name_cols('_rolling_mean', cols))))
    rolling_std_contest_cols = df.groupby('idx')[cols].transform(lambda x: x.rolling(window=3, min_periods=2).std()) \
        .rename(columns=dict(zip(cols, get_name_cols('_rolling_std', cols))))
    # expanding_mean_contest_cols = df.groupby('idx')[cols].transform(lambda x: x.expanding(2).mean()) \
    #     .rename(columns=dict(zip(cols, get_name_cols('_expanding_mean', cols))))
    # expanding_std_contest_cols = df.groupby('idx')[cols].transform(lambda x: x.expanding(2).std()) \
    #     .rename(columns=dict(zip(cols, get_name_cols('_expanding_std', cols))))
    # diff_contest_cols = df.groupby('idx')[contest_cols].transform(lambda x: x.diff()) \
    #     .rename(columns=dict(zip(cols, get_name_cols('_diff'))))
    exponentially_weighted_average = df.groupby('idx')[cols].transform(lambda x: x.shift(1).ewm(alpha=0.95).mean()) \
        .rename(columns=dict(zip(cols, get_name_cols('_ewa', cols))))

    df = pd.concat([df, rolling_mean_contest_cols, rolling_std_contest_cols, exponentially_weighted_average], axis=1)
    df = df.fillna(method='bfill')
    
    return df

# %%
imp_contest_cols = [
    'contest-pevpr-sfc-gauss-14d__pevpr',
    'contest-pres-sfc-gauss-14d__pres',
    'contest-prwtr-eatm-14d__prwtr',
    'contest-slp-14d__slp',
    'contest-wind-h10-14d__wind-hgt-10',
    'contest-wind-h100-14d__wind-hgt-100',
    'contest-wind-h500-14d__wind-hgt-500',
    'contest-wind-uwnd-250-14d__wind-uwnd-250',
    'contest-wind-vwnd-925-14d__wind-vwnd-925'
]

df_train = feature_engineer(df_train, imp_contest_cols)
df_test = feature_engineer(df_test, imp_contest_cols)

# %%
col_ = [each for each in df_train.columns if "_rolling" in each or "_ewa" in each]
list_new_col = [*list_new_col, *col_]

# %%
for each in list_new_col:
    try: 
        corr, _ = pearsonr(df_train[each], df_train[target_])
        print(f"{each}: {round(corr, 5)}")
    except:
        print(f"Cate col: {each}")
# Out:
# Cate col: nmme-tmp2m-34w__nmmemean_bin
# Cate col: nmme-tmp2m-56w__nmmemean_bin
# Cate col: nmme0-tmp2m-34w__nmme0mean_bin
# Cate col: nmme0mean_bin
# contest-pevpr-sfc-gauss-14d__pevpr_lag_1: 0.80444
# contest-pevpr-sfc-gauss-14d__pevpr_lag_2: 0.80296
# contest-wind-h10-14d__wind-hgt-10_lag_1: 0.76435
# contest-wind-h10-14d__wind-hgt-10_lag_2: 0.76479
# contest-rhum-sig995-14d__rhum_lag_1: -0.56272
# contest-rhum-sig995-14d__rhum_lag_2: -0.55949
# contest-wind-h100-14d__wind-hgt-100_lag_1: 0.89578
# contest-wind-h100-14d__wind-hgt-100_lag_2: 0.89251
# contest-slp-14d__slp_lag_1: -0.70183
# contest-slp-14d__slp_lag_2: -0.695
# contest-wind-vwnd-925-14d__wind-vwnd-925_lag_1: 0.27221
# contest-wind-vwnd-925-14d__wind-vwnd-925_lag_2: 0.26921
# contest-pres-sfc-gauss-14d__pres_lag_1: 0.24456
# contest-pres-sfc-gauss-14d__pres_lag_2: 0.2448
# contest-wind-uwnd-250-14d__wind-uwnd-250_lag_1: -0.33044
# contest-wind-uwnd-250-14d__wind-uwnd-250_lag_2: -0.33319
# contest-prwtr-eatm-14d__prwtr_lag_1: 0.77026
# contest-prwtr-eatm-14d__prwtr_lag_2: 0.76757
# contest-wind-vwnd-250-14d__wind-vwnd-250_lag_1: 0.42907
# contest-wind-vwnd-250-14d__wind-vwnd-250_lag_2: 0.42655
# contest-precip-14d__precip_lag_1: 0.07767
# contest-precip-14d__precip_lag_2: 0.07705
# contest-wind-h850-14d__wind-hgt-850_lag_1: 0.50156
# contest-wind-h850-14d__wind-hgt-850_lag_2: 0.50483
# contest-wind-uwnd-925-14d__wind-uwnd-925_lag_1: -0.36683
# contest-wind-uwnd-925-14d__wind-uwnd-925_lag_2: -0.36789
# contest-wind-h500-14d__wind-hgt-500_lag_1: 0.88361
# contest-wind-h500-14d__wind-hgt-500_lag_2: 0.88148
# wind-vwnd-250-2010-1_diff: -0.04805
# wind-vwnd-250-2010-1_lag_1: -0.72895
# wind-vwnd-250-2010-3_diff: -0.05364
# wind-vwnd-250-2010-3_lag_1: -0.1744
# wind-vwnd-250-2010-4_diff: 0.02271
# wind-vwnd-250-2010-4_lag_1: -0.14766
# wind-vwnd-250-2010-5_diff: 0.00084
# wind-vwnd-250-2010-5_lag_1: -0.10484
# contest-wind-h100-14d__wind-hgt-100_ewa: 0.89564
# contest-wind-h500-14d__wind-hgt-500_ewa: 0.88359
# contest-wind-uwnd-250-14d__wind-uwnd-250_ewa: -0.33076
# contest-wind-vwnd-925-14d__wind-vwnd-925_ewa: 0.27225

# %%
df_train = df_train.drop(columns=["idx"])
df_test = df_test.drop(columns=["idx"])

# %% [markdown]
# # Plot dis

# %%
df_train_copy = df_train.copy()
df_test_copy = df_test.copy()
df_train_copy["type_data"] = ["train" for i in range(len(df_train))]
df_test_copy["type_data"] = ["test" for i in range(len(df_test))]

df_total = pd.concat([df_train_copy, df_test_copy]).reset_index(drop=True)

# %%
n_cols = 4
n_rows = len(list_new_col) // n_cols + (len(list_new_col) % n_cols != 0)
f, axes = plt.subplots(n_rows, n_cols, figsize=(20, 250))
count_cols, count_rows = 0, 0

# df_sample = df_total[df_total["is_driff"] == 0].reset_index(drop=True)
# df_test_non_driff = df_test[df_test["is_driff"] == 0].reset_index(drop=True)
for each in list_new_col:
    try:
        sns.kdeplot(x=each, data=df_total, hue='type_data', common_norm=False, ax=axes[count_rows][count_cols])
        count_cols += 1
        count_rows += 1 if count_cols % n_cols == 0 else 0
        count_cols = count_cols % n_cols
    except:
        pass
f.tight_layout(h_pad=6)

# %% [markdown]
# # Tuning hyperparameters

# %%
def bayes_tunning():
    def CB_opt(max_depth, num_leaves, colsample_bytree, reg_alpha, reg_lambda, subsample, feature_fraction_bynode):
        
        bin_col = ['nmme-tmp2m-34w__nmmemean', 'nmme-tmp2m-56w__nmmemean', 'nmme0-tmp2m-34w__nmme0mean', 'nmme0mean']
        bin_col = [each + "_bin" for each in bin_col]
        cat_ft = [*bin_col, *["climateregions__climateregion", "idx", "mjo1d__phase"]]
        # cat_ft = ["climateregions__climateregion", "idx", "mjo1d__phase"]
        
        lgb = LGBMRegressor(metric="rmse", boosting_type="dart", 
                            max_depth = round(max_depth), n_estimators = 7999, 
                            subsample=subsample, colsample_bytree=colsample_bytree, 
                            reg_alpha=reg_alpha, reg_lambda=reg_lambda,
                            feature_fraction_bynode=feature_fraction_bynode,
                            num_leaves=round(num_leaves), verbose=0)
        
        lgb.fit(X_train, y_train, eval_metric="rmse", categorical_feature=cat_ft)
        ypred_valid = lgb.predict(X_valid)

        return 1 / mean_squared_error(y_valid, ypred_valid, squared=False)

    pbounds = {
        "max_depth": (9, 17),
        'num_leaves': (14, 30),
        'colsample_bytree': (0.45, 0.75),
        'reg_alpha': (0.1, 5.2), 
        'reg_lambda': (0.1, 3.2),
        'subsample': (0.65, 0.85),
        'feature_fraction_bynode': (0.65, 0.9)
    }
    
    path_tunning = "Params_tunning/Log/logs_dart_6_new_fe_ver1.json".format(index)
    optimizer = BayesianOptimization(f = CB_opt, pbounds = pbounds, verbose = 2)
    # if os.path.exists(path_tunning) is False:
    #     logger = JSONLogger(path=path_tunning, reset=False)
    #     optimizer.subscribe(Events.OPTIMIZATION_STEP, logger)
    #     optimizer.maximize(init_points = 1, n_iter = 4)
    # else:
    #     load_logs(optimizer, logs=[path_tunning])
    logger = JSONLogger(path=path_tunning, reset=False)
    optimizer.subscribe(Events.OPTIMIZATION_STEP, logger)
    optimizer.maximize(init_points = 6, n_iter = 27)    
    print(optimizer.max['target'])

    max_bo_params = optimizer.max['params']

    return max_bo_params

# %%
dict_result = [6]

# %%
year_valid = [2014, 2014, 2015, 2015, 2015, 2015, 2015, 2015, 2016, 2016, 2016, 2016]
month_valid = [9, 11, 1, 3, 5, 7, 9, 11, 1, 3, 5, 7]
gap = 1
for index in range(len(year_valid)):
    if index not in dict_result:
        continue
    #thay code   
    m_s, m_e = month_valid[index], month_valid[index] + gap
    y_s, y_e = year_valid[index], year_valid[index]
    y_e = y_e + 1 if m_e > 12 else y_e
    m_e = m_e if m_e <= 12 else ((m_e - 12) % 12)
    if y_e != y_s:
        X_valid = df_train[((df_train[date_col].dt.year == y_s) & (df_train[date_col].dt.month >= m_s)) | ((df_train[date_col].dt.month <= m_e) & (df_train[date_col].dt.month == y_e))]
        X_train = df_train[~(((df_train[date_col].dt.year == y_s) & (df_train[date_col].dt.month >= m_s)) | ((df_train[date_col].dt.month <= m_e) & (df_train[date_col].dt.month == y_e)))]
    else:
        X_valid = df_train[(df_train[date_col].dt.year == y_s) & (df_train[date_col].dt.month >= m_s) & (df_train[date_col].dt.month <= m_e)]
        X_train = df_train[~((df_train[date_col].dt.year == y_s) & (df_train[date_col].dt.month >= m_s) & (df_train[date_col].dt.month <= m_e))]
    #drop hết cột mới
    
    y_train = X_train[target_]
    X_train = X_train.drop(columns=["index", target_])
    y_valid = X_valid[target_]
    X_valid = X_valid.drop(columns=["index", target_])
    
    test_index = df_test["index"].values
    X_test = df_test.drop(columns=["index"]).copy()

    cat_cols = [i for i in X_train.select_dtypes(include='object').columns if i != date_col]
    X_train, X, listEncoder = handle_data.handle_feature_train_data(X_train, date_col, cat_cols.copy(), norm="none")
    X_valid = handle_data.handle_feature_test_data(X_valid, listEncoder, columns_cat=cat_cols.copy()) 
    X_test = handle_data.handle_feature_test_data(X_test, listEncoder, columns_cat=cat_cols.copy())
    
    drop_mei = [each for each in X_train.columns if "mei" in each]
    drop_ = [*drop_col, *["month", "day_of_year", "day_of_year_sin", "day_of_year_cos", "month_sin", "month_cos"], *drop_mei, *col_drift]
    
    X_train = X_train.drop(columns=drop_)
    X_valid = X_valid.drop(columns=drop_)
    X_test = X_test.drop(columns=drop_)
    
    print("Training - {}".format(index))
    t= time.time()
    max_bo_params = bayes_tunning()
    with open("Params_tunning/dict_dart_{}_new_fe.pickle".format(index), "wb") as file:
        pickle.dump(max_bo_params, file)
     
    print("Take time: ", time.time() - t)
    print("-------------")
# Out:
# Training - 6
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.481924 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.717715 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.709103 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.516708 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.522270 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.629013 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.604171 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.532986 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.502948 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.493677 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.613624 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.590754 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.687079 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.528882 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.480743 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.647177 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.514042 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.632244 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.623322 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.625198 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.601180 seconds.
# You can set `force_col_wise=true` to remove the overhead.

# %%
dict_result = {}

# %% [markdown]
# # Run model

# %%
params = {"target": 1.6328136155725321, "params": {"colsample_bytree": 0.75, "feature_fraction_bynode": 0.9, "max_depth": 11.186366350741467, "num_leaves": 14.0, "reg_alpha": 3.2, "reg_lambda": 1.2, "subsample": 0.85}, "datetime": {"datetime": "2023-02-21 04:22:21", "elapsed": 20150.435182, "delta": 1645.855422}}
params = params["params"]

# %%
params
# Out:
# {'colsample_bytree': 0.75,
#  'feature_fraction_bynode': 0.65,
#  'max_depth': 9.0,
#  'num_leaves': 14.0,
#  'reg_alpha': 5.2,
#  'reg_lambda': 0.1,
#  'subsample': 0.85}

# %%
year_valid = [2014, 2014, 2015, 2015, 2015, 2015, 2015, 2015, 2016, 2016, 2016, 2016]
month_valid = [9, 11, 1, 3, 5, 7, 9, 11, 1, 3, 5, 7]
gap = 1
for index in range(len(year_valid)):
    if index in dict_result:
        continue
    m_s, m_e = month_valid[index], month_valid[index] + gap
    y_s, y_e = year_valid[index], year_valid[index]
    y_e = y_e + 1 if m_e > 12 else y_e
    m_e = m_e if m_e <= 12 else ((m_e - 12) % 12)
    if y_e != y_s:
        X_valid = df_train[((df_train[date_col].dt.year == y_s) & (df_train[date_col].dt.month >= m_s)) | ((df_train[date_col].dt.month <= m_e) & (df_train[date_col].dt.month == y_e))]
        X_train = df_train[~(((df_train[date_col].dt.year == y_s) & (df_train[date_col].dt.month >= m_s)) | ((df_train[date_col].dt.month <= m_e) & (df_train[date_col].dt.month == y_e)))]
    else:
        X_valid = df_train[(df_train[date_col].dt.year == y_s) & (df_train[date_col].dt.month >= m_s) & (df_train[date_col].dt.month <= m_e)]
        X_train = df_train[~((df_train[date_col].dt.year == y_s) & (df_train[date_col].dt.month >= m_s) & (df_train[date_col].dt.month <= m_e))]
    
    y_train = X_train[target_]
    X_train = X_train.drop(columns=["index", target_])
    y_valid = X_valid[target_]
    X_valid = X_valid.drop(columns=["index", target_])
    
    test_index = df_test["index"].values
    X_test = df_test.drop(columns=["index"]).copy()

    cat_cols = [i for i in X_train.select_dtypes(include='object').columns if i != date_col]
    X_train, X, listEncoder = handle_data.handle_feature_train_data(X_train, date_col, cat_cols.copy(), norm="none")
    X_valid = handle_data.handle_feature_test_data(X_valid, listEncoder, columns_cat=cat_cols.copy()) 
    X_test = handle_data.handle_feature_test_data(X_test, listEncoder, columns_cat=cat_cols.copy())
    # X_sm = handle_data.handle_feature_test_data(X_oversampling_smote.copy(), listEncoder, df_mean, columns_cat=cat_cols.copy(), column_date=None)
    
    # y_sm = X_sm[target_]
    # X_sm = X_sm.drop(columns=[*["mei__nip", target_], *bin_col])
    
    drop_mei = [each for each in X_train.columns if "mei" in each]
    drop_ = [*drop_col, *["month", "day_of_year", "day_of_year_sin", "day_of_year_cos", "month_sin", "month_cos"], *drop_mei, *col_drift]
    
    # X_train_1 = X_train.drop(columns=drop_1)
    # X_valid_1 = X_valid.drop(columns=drop_1)
    # X_test_1 = X_test.drop(columns=drop_1)
    
    X_train = X_train.drop(columns=drop_)
    X_valid = X_valid.drop(columns=drop_)
    X_test = X_test.drop(columns=drop_)
    
    # X_train = pd.concat([X_train, X_sm])
    # y_train = [*y_train, *y_sm]
    cat_ft = [*cat_cols, *['idx', "mjo1d__phase"]]

        
    print("Training - {}".format(index))
    t= time.time()
    # lgb = LGBMRegressor(metric="rmse", boosting_type="dart", max_depth = 16, n_estimators = 8999, subsample=0.75, colsample_bytree=0.75, 
    #                     reg_alpha=0.5, reg_lambda=0.5, verbose=0)
    # lgb.fit(X_train, y_train, eval_metric="rmse", categorical_feature=["climateregions__climateregion", "idx"])
    # lgb = LGBMRegressor(max_depth = 15, n_estimators = 4999, subsample=0.75, colsample_bytree=0.75, verbose=0)
     
    # with open("Params_tunning/dict_dart_{}_col.pickle".format(index), "rb") as file:
    #     params = pickle.load(file)
   
    if index == 0:
        print(cat_ft)
    lgb = LGBMRegressor(metric="rmse", boosting_type="dart", max_depth = round(params["max_depth"]), n_estimators = 7999, 
                        subsample=params["subsample"], colsample_bytree=params["colsample_bytree"], num_leaves=round(params["num_leaves"]),
                        reg_alpha=params["reg_alpha"], reg_lambda=params["reg_lambda"], feature_fraction_bynode=params["feature_fraction_bynode"],
                        verbose=0)
    # lgb_1 = LGBMRegressor(max_depth = 15, n_estimators = 1999, subsample=0.75, colsample_bytree=0.75, verbose=0) 
    
    # lgb = LGBMRegressor(metric="rmse", boosting_type="dart", max_depth = 16, n_estimators = 7999, subsample=0.7, colsample_bytree=0.7, 
    #                      reg_alpha=0.3, reg_lambda=0.1, verbose=0)
    lgb.fit(X_train, y_train, eval_metric="rmse", categorical_feature=cat_ft)
    lgb.booster_.save_model('Model/model_dart_{}_new_col.txt'.format(index))
    # lgb_1.fit(X_train_1, y_train, eval_metric="rmse", categorical_feature=["climateregions__climateregion", "idx"])
    
    result_train = mean_squared_error(y_train, lgb.predict(X_train), squared=False)
    result_valid = mean_squared_error(y_valid, lgb.predict(X_valid), squared=False)    
    
    # result_train_1 = mean_squared_error(y_train, lgb_1.predict(X_train_1), squared=False)
    # result_valid_1 = mean_squared_error(y_valid, lgb_1.predict(X_valid_1), squared=False)  
    
    ypred_test = lgb.predict(X_test) 
    # ypred_test_1 = lgb_1.predict(X_test_1)
    
    dict_result[index] = ypred_test
    # dict_result_1[index] = ypred_test_1
    
    print("Take time: ", time.time() - t)
    print("Train_score: {}  Valid_score: {}".format(result_train, result_valid))
    # print("Train_score_: {}  Valid_score_: {}".format(result_train_1, result_valid_1))
    print("-------------")
# Out:
# Training - 7
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.572429 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# Take time:  1703.636391878128
# Train_score: 0.20278565018760022  Valid_score: 1.3858856163857631
# -------------
# Training - 8
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.625573 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# Take time:  1762.5024526119232
# Train_score: 0.20049359313636209  Valid_score: 1.3339288349648584
# -------------
# Training - 9
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.576052 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# Take time:  1724.1370990276337
# Train_score: 0.2042259694886196  Valid_score: 1.0678762131464805
# -------------
# Training - 10
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.580665 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# Take time:  1739.1508567333221
# Train_score: 0.20709063237992448  Valid_score: 0.6714003834891756
# -------------
# Training - 11
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.600776 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# Take time:  1905.7250380516052
# Train_score: 0.2054750504896315  Valid_score: 0.6104590195280357
# -------------

# %%
result_valid
# Out:
# 0.6683940744711073

# %%
dict_result
# Out:
# {6: True,
#  0: array([29.28658974, 29.31585449, 29.34350867, ...,  6.11133959,
#          6.24849004,  6.4601141 ]),
#  1: array([29.28316238, 29.25429377, 29.35201372, ...,  5.97778178,
#          5.9121879 ,  6.26908729]),
#  2: array([29.35235617, 29.34094262, 29.25909558, ...,  5.47735864,
#          5.63094354,  5.84737485]),
#  3: array([29.36262103, 29.33616504, 29.35179165, ...,  5.73280944,
#          5.59667642,  5.83948443]),
#  4: array([29.36797508, 29.3537477 , 29.32892286, ...,  5.31669253,
#          5.2358517 ,  5.76573137]),
#  5: array([29.24411431, 29.27578715, 29.28016752, ...,  5.59031142,
#          5.77926369,  5.95384459]),
#  7: array([29.41356579, 29.48854148, 29.43402263, ...,  5.41660592,
#          5.60725419,  5.89594262]),
#  8: array([29.30903829, 29.31070231, 29.31781805, ...,  5.48192629,
#          5.62803973,  5.99663347]),
#  9: array([29.39679769, 29.4249583 , 29.45106257, ...,  6.19095759,
#          6.25731831,  6.4750638 ]),
#  10: array([29.38822738, 29.34749864, 29.31376684, ...,  5.72738921,
#          5.83634332,  6.17232367]),
#  11: array([29.52233436, 29.52026917, 29.60781951, ...,  5.39977831,
#          5.46198878,  5.69579356])}

# %%
ypred_test = np.mean([value for key, value in dict_result.items() if key == 11], axis=0)
# ypred_test_early = np.mean([value for key, value in dict_result_early.items()], axis=0)
pd.DataFrame(data = {"{}".format(target_): ypred_test, "index": test_index}).to_csv("Data/submit_tunning.csv", index=False)

# %%
mean_squared_error(y_valid, lgb.predict(X_valid), squared=False)
# Out:
# 0.6302122355070707

# %%
dict(zip(lgb.feature_name_, lgb.feature_importances_))
# Out:
# {'lat': 561,
#  'lon': 521,
#  'contest-pevpr-sfc-gauss-14d__pevpr': 4463,
#  'contest-wind-h10-14d__wind-hgt-10': 212,
#  'contest-rhum-sig995-14d__rhum': 340,
#  'nmme-prate-34w__cancm3': 154,
#  'nmme-prate-34w__cancm4': 127,
#  'nmme-prate-34w__ccsm3': 195,
#  'nmme-prate-34w__ccsm4': 162,
#  'nmme-prate-34w__cfsv2': 174,
#  'nmme-prate-34w__gfdl': 543,
#  'nmme-prate-34w__gfdlflora': 134,
#  'nmme-prate-34w__gfdlflorb': 241,
#  'nmme-prate-34w__nasa': 152,
#  'nmme-prate-34w__nmmemean': 65,
#  'contest-wind-h100-14d__wind-hgt-100': 2652,
#  'nmme0-prate-56w__cancm30': 155,
#  'nmme0-prate-56w__cancm40': 173,
#  'nmme0-prate-56w__ccsm30': 400,
#  'nmme0-prate-56w__ccsm40': 99,
#  'nmme0-prate-56w__cfsv20': 136,
#  'nmme0-prate-56w__gfdlflora0': 105,
#  'nmme0-prate-56w__gfdlflorb0': 120,
#  'nmme0-prate-56w__gfdl0': 103,
#  'nmme0-prate-56w__nasa0': 98,
#  'nmme0-prate-56w__nmme0mean': 92,
#  'nmme0-prate-34w__cancm30': 349,
#  'nmme0-prate-34w__cancm40': 234,
#  'nmme0-prate-34w__ccsm30': 294,
#  'nmme0-prate-34w__ccsm40': 87,
#  'nmme0-prate-34w__cfsv20': 104,
#  'nmme0-prate-34w__gfdlflora0': 86,
#  'nmme0-prate-34w__gfdlflorb0': 129,
#  'nmme0-prate-34w__gfdl0': 338,
#  'nmme0-prate-34w__nasa0': 73,
#  'nmme0-prate-34w__nmme0mean': 118,
#  'contest-slp-14d__slp': 5067,
#  'wind-vwnd-925-2010-6': 126,
#  'wind-vwnd-925-2010-7': 150,
#  'wind-vwnd-925-2010-8': 60,
#  'wind-vwnd-925-2010-9': 13,
#  'wind-vwnd-925-2010-10': 28,
#  'wind-vwnd-925-2010-11': 40,
#  'wind-vwnd-925-2010-12': 24,
#  'wind-vwnd-925-2010-13': 41,
#  'wind-vwnd-925-2010-14': 58,
#  'wind-vwnd-925-2010-15': 72,
#  'wind-vwnd-925-2010-16': 49,
#  'wind-vwnd-925-2010-17': 38,
#  'wind-vwnd-925-2010-18': 82,
#  'wind-vwnd-925-2010-19': 35,
#  'wind-vwnd-925-2010-20': 24,
#  'nmme-tmp2m-34w__nmmemean_bin': 3747,
#  'nmme-tmp2m-56w__nmmemean_bin': 4611,
#  'nmme0-tmp2m-34w__nmme0mean_bin': 747,
#  'nmme0mean_bin': 836,
#  'contest-pevpr-sfc-gauss-14d__pevpr_lag_1': 474,
#  'contest-pevpr-sfc-gauss-14d__pevpr_lag_2': 218,
#  'contest-wind-h10-14d__wind-hgt-10_lag_1': 85,
#  'contest-wind-h10-14d__wind-hgt-10_lag_2': 165,
#  'contest-rhum-sig995-14d__rhum_lag_1': 43,
#  'contest-rhum-sig995-14d__rhum_lag_2': 26,
#  'contest-wind-h100-14d__wind-hgt-100_lag_1': 342,
#  'contest-wind-h100-14d__wind-hgt-100_lag_2': 317,
#  'contest-slp-14d__slp_lag_1': 273,
#  'contest-slp-14d__slp_lag_2': 350,
#  'contest-wind-vwnd-925-14d__wind-vwnd-925_lag_1': 81,
#  'contest-wind-vwnd-925-14d__wind-vwnd-925_lag_2': 146,
#  'contest-pres-sfc-gauss-14d__pres_lag_1': 772,
#  'contest-pres-sfc-gauss-14d__pres_lag_2': 1132,
#  'contest-wind-uwnd-250-14d__wind-uwnd-250_lag_1': 70,
#  'contest-wind-uwnd-250-14d__wind-uwnd-250_lag_2': 109,
#  'contest-prwtr-eatm-14d__prwtr_lag_1': 672,
#  'contest-prwtr-eatm-14d__prwtr_lag_2': 1335,
#  'contest-wind-vwnd-250-14d__wind-vwnd-250_lag_1': 52,
#  'contest-wind-vwnd-250-14d__wind-vwnd-250_lag_2': 86,
#  'contest-precip-14d__precip_lag_1': 61,
#  'contest-precip-14d__precip_lag_2': 106,
#  'contest-wind-h850-14d__wind-hgt-850_lag_1': 261,
#  'contest-wind-h850-14d__wind-hgt-850_lag_2': 83,
#  'contest-wind-uwnd-925-14d__wind-uwnd-925_lag_1': 73,
#  'contest-wind-uwnd-925-14d__wind-uwnd-925_lag_2': 45,
#  'contest-wind-h500-14d__wind-hgt-500_lag_1': 814,
#  'contest-wind-h500-14d__wind-hgt-500_lag_2': 320,
#  'wind-vwnd-250-2010-1_lag_1': 94,
#  'wind-vwnd-250-2010-2_lag_1': 26,
#  'wind-vwnd-250-2010-3_lag_1': 36,
#  'wind-vwnd-250-2010-4_lag_1': 120,
#  'wind-vwnd-250-2010-5_lag_1': 43,
#  'wind-vwnd-250-2010-6_lag_1': 22,
#  'wind-vwnd-250-2010-7_lag_1': 16,
#  'wind-vwnd-925-2010-10_lag_1': 27,
#  'wind-vwnd-925-2010-11_lag_1': 47,
#  'wind-vwnd-925-2010-12_lag_1': 32,
#  'wind-vwnd-925-2010-13_lag_1': 42,
#  'wind-vwnd-925-2010-14_lag_1': 74,
#  'wind-vwnd-925-2010-15_lag_1': 47,
#  'wind-vwnd-925-2010-16_lag_1': 57,
#  'wind-vwnd-925-2010-17_lag_1': 29,
#  'wind-vwnd-925-2010-18_lag_1': 66,
#  'wind-vwnd-925-2010-19_lag_1': 24,
#  'wind-vwnd-925-2010-20_lag_1': 19,
#  'contest-pevpr-sfc-gauss-14d__pevpr_lat_mean': 3642,
#  'contest-pevpr-sfc-gauss-14d__pevpr_lon_mean': 176,
#  'contest-pevpr-sfc-gauss-14d__pevpr_climateregions__climateregion_mean': 1814,
#  'contest-wind-h10-14d__wind-hgt-10_lat_mean': 159,
#  'contest-wind-h10-14d__wind-hgt-10_lon_mean': 384,
#  'contest-wind-h10-14d__wind-hgt-10_climateregions__climateregion_mean': 239,
#  'contest-rhum-sig995-14d__rhum_lat_mean': 315,
#  'contest-rhum-sig995-14d__rhum_lon_mean': 99,
#  'contest-rhum-sig995-14d__rhum_climateregions__climateregion_mean': 82,
#  'contest-wind-h100-14d__wind-hgt-100_lat_mean': 355,
#  'contest-wind-h100-14d__wind-hgt-100_lon_mean': 241,
#  'contest-wind-h100-14d__wind-hgt-100_climateregions__climateregion_mean': 379,
#  'contest-slp-14d__slp_lat_mean': 99,
#  'contest-slp-14d__slp_lon_mean': 605,
#  'contest-slp-14d__slp_climateregions__climateregion_mean': 288,
#  'contest-wind-vwnd-925-14d__wind-vwnd-925_lat_mean': 219,
#  'contest-wind-vwnd-925-14d__wind-vwnd-925_lon_mean': 188,
#  'contest-wind-vwnd-925-14d__wind-vwnd-925_climateregions__climateregion_mean': 88,
#  'contest-pres-sfc-gauss-14d__pres_lat_mean': 327,
#  'contest-pres-sfc-gauss-14d__pres_lon_mean': 216,
#  'contest-pres-sfc-gauss-14d__pres_climateregions__climateregion_mean': 229,
#  'contest-wind-uwnd-250-14d__wind-uwnd-250_lat_mean': 189,
#  'contest-wind-uwnd-250-14d__wind-uwnd-250_lon_mean': 419,
#  'contest-wind-uwnd-250-14d__wind-uwnd-250_climateregions__climateregion_mean': 91,
#  'contest-prwtr-eatm-14d__prwtr_lat_mean': 1710,
#  'contest-prwtr-eatm-14d__prwtr_lon_mean': 270,
#  'contest-prwtr-eatm-14d__prwtr_climateregions__climateregion_mean': 1292,
#  'contest-wind-vwnd-250-14d__wind-vwnd-250_lat_mean': 69,
#  'contest-wind-vwnd-250-14d__wind-vwnd-250_lon_mean': 171,
#  'contest-wind-vwnd-250-14d__wind-vwnd-250_climateregions__climateregion_mean': 34,
#  'contest-precip-14d__precip_lat_mean': 191,
#  'contest-precip-14d__precip_lon_mean': 138,
#  'contest-precip-14d__precip_climateregions__climateregion_mean': 32,
#  'contest-wind-h850-14d__wind-hgt-850_lat_mean': 304,
#  'contest-wind-h850-14d__wind-hgt-850_lon_mean': 101,
#  'contest-wind-h850-14d__wind-hgt-850_climateregions__climateregion_mean': 85,
#  'contest-wind-uwnd-925-14d__wind-uwnd-925_lat_mean': 168,
#  'contest-wind-uwnd-925-14d__wind-uwnd-925_lon_mean': 134,
#  'contest-wind-uwnd-925-14d__wind-uwnd-925_climateregions__climateregion_mean': 36,
#  'contest-wind-h500-14d__wind-hgt-500_lat_mean': 822,
#  'contest-wind-h500-14d__wind-hgt-500_lon_mean': 728,
#  'contest-wind-h500-14d__wind-hgt-500_climateregions__climateregion_mean': 1189,
#  'contest-pevpr-sfc-gauss-14d__pevpr_rolling_mean': 1199,
#  'contest-wind-h10-14d__wind-hgt-10_rolling_mean': 127,
#  'contest-rhum-sig995-14d__rhum_rolling_mean': 85,
#  'contest-wind-h100-14d__wind-hgt-100_rolling_mean': 769,
#  'contest-slp-14d__slp_rolling_mean': 1049,
#  'contest-wind-vwnd-925-14d__wind-vwnd-925_rolling_mean': 286,
#  'contest-pres-sfc-gauss-14d__pres_rolling_mean': 1055,
#  'contest-wind-uwnd-250-14d__wind-uwnd-250_rolling_mean': 106,
#  'contest-prwtr-eatm-14d__prwtr_rolling_mean': 2112,
#  'contest-wind-vwnd-250-14d__wind-vwnd-250_rolling_mean': 63,
#  'contest-precip-14d__precip_rolling_mean': 103,
#  'contest-wind-h850-14d__wind-hgt-850_rolling_mean': 79,
#  'contest-wind-uwnd-925-14d__wind-uwnd-925_rolling_mean': 146,
#  'contest-wind-h500-14d__wind-hgt-500_rolling_mean': 1582,
#  'contest-pevpr-sfc-gauss-14d__pevpr_rolling_std': 14,
#  'contest-wind-h10-14d__wind-hgt-10_rolling_std': 42,
#  'contest-rhum-sig995-14d__rhum_rolling_std': 6,
#  'contest-wind-h100-14d__wind-hgt-100_rolling_std': 34,
#  'contest-slp-14d__slp_rolling_std': 5,
#  'contest-wind-vwnd-925-14d__wind-vwnd-925_rolling_std': 9,
#  'contest-pres-sfc-gauss-14d__pres_rolling_std': 2,
#  'contest-wind-uwnd-250-14d__wind-uwnd-250_rolling_std': 11,
#  'contest-prwtr-eatm-14d__prwtr_rolling_std': 6,
#  'contest-wind-vwnd-250-14d__wind-vwnd-250_rolling_std': 10,
#  'contest-precip-14d__precip_rolling_std': 1,
#  'contest-wind-h850-14d__wind-hgt-850_rolling_std': 2,
#  'contest-wind-uwnd-925-14d__wind-uwnd-925_rolling_std': 7,
#  'contest-wind-h500-14d__wind-hgt-500_rolling_std': 41,
#  'contest-pevpr-sfc-gauss-14d__pevpr_ewa': 291,
#  'contest-wind-h10-14d__wind-hgt-10_ewa': 81,
#  'contest-rhum-sig995-14d__rhum_ewa': 31,
#  'contest-wind-h100-14d__wind-hgt-100_ewa': 327,
#  'contest-slp-14d__slp_ewa': 230,
#  'contest-wind-vwnd-925-14d__wind-vwnd-925_ewa': 90,
#  'contest-pres-sfc-gauss-14d__pres_ewa': 781,
#  'contest-wind-uwnd-250-14d__wind-uwnd-250_ewa': 78,
#  'contest-prwtr-eatm-14d__prwtr_ewa': 697,
#  'contest-wind-vwnd-250-14d__wind-vwnd-250_ewa': 52,
#  'contest-precip-14d__precip_ewa': 60,
#  'contest-wind-h850-14d__wind-hgt-850_ewa': 176,
#  'contest-wind-uwnd-925-14d__wind-uwnd-925_ewa': 57,
#  'contest-wind-h500-14d__wind-hgt-500_ewa': 476,
#  'idx': 35137}

# %%
# lgb_ = lightgbm.Booster(model_file="Model/model_dart_fe_6.txt")
dict_ = dict(zip(lgb.feature_name_, lgb.feature_importances_))
sorted(dict_.items(), key=lambda x: x[1], reverse=True), len(dict_)
# Out:
# ([('idx', 35137),
#   ('contest-wind-h500-14d__wind-hgt-500', 8391),
#   ('contest-slp-14d__slp', 5067),
#   ('nmme-tmp2m-56w__nmmemean_bin', 4611),
#   ('contest-pevpr-sfc-gauss-14d__pevpr', 4463),
#   ('contest-prwtr-eatm-14d__prwtr', 3993),
#   ('nmme-tmp2m-34w__nmmemean_bin', 3747),
#   ('contest-pevpr-sfc-gauss-14d__pevpr_lat_mean', 3642),
#   ('contest-wind-h100-14d__wind-hgt-100', 2652),
#   ('climateregions__climateregion', 2455),
#   ('contest-prwtr-eatm-14d__prwtr_rolling_mean', 2112),
#   ('contest-pevpr-sfc-gauss-14d__pevpr_climateregions__climateregion_mean',
#    1814),
#   ('contest-prwtr-eatm-14d__prwtr_lat_mean', 1710),
#   ('contest-wind-h500-14d__wind-hgt-500_rolling_mean', 1582),
#   ('elevation__elevation', 1448),
#   ('contest-prwtr-eatm-14d__prwtr_lag_2', 1335),
#   ('contest-prwtr-eatm-14d__prwtr_climateregions__climateregion_mean', 1292),
#   ('contest-pevpr-sfc-gauss-14d__pevpr_rolling_mean', 1199),
#   ('contest-wind-h500-14d__wind-hgt-500_climateregions__climateregion_mean',
#    1189),
#   ('contest-pres-sfc-gauss-14d__pres_lag_2', 1132),
#   ('contest-pres-sfc-gauss-14d__pres_rolling_mean', 1055),
#   ('contest-slp-14d__slp_rolling_mean', 1049),
#   ('nmme0mean_bin', 836),
#   ('contest-wind-h500-14d__wind-hgt-500_lat_mean', 822),
#   ('contest-wind-h500-14d__wind-hgt-500_lag_1', 814),
#   ('contest-pres-sfc-gauss-14d__pres', 789),
#   ('contest-pres-sfc-gauss-14d__pres_ewa', 781),
#   ('contest-pres-sfc-gauss-14d__pres_lag_1', 772),
#   ('contest-wind-h100-14d__wind-hgt-100_rolling_mean', 769),
#   ('contest-wind-vwnd-925-14d__wind-vwnd-925', 759),
#   ('nmme0-tmp2m-34w__nmme0mean_bin', 747),
#   ('nmme-prate-56w__gfdl', 734),
#   ('contest-wind-h500-14d__wind-hgt-500_lon_mean', 728),
#   ('contest-prwtr-eatm-14d__prwtr_ewa', 697),
#   ('contest-prwtr-eatm-14d__prwtr_lag_1', 672),
#   ('contest-slp-14d__slp_lon_mean', 605),
#   ('sst-2010-1_lag_1', 588),
#   ('lat', 561),
#   ('nmme-prate-34w__gfdl', 543),
#   ('sst-2010-1', 524),
#   ('lon', 521),
#   ('contest-wind-h500-14d__wind-hgt-500_ewa', 476),
#   ('contest-pevpr-sfc-gauss-14d__pevpr_lag_1', 474),
#   ('contest-wind-h850-14d__wind-hgt-850', 464),
#   ('contest-precip-14d__precip', 445),
#   ('wind-vwnd-250-2010-11_lag_1', 442),
#   ('contest-wind-uwnd-250-14d__wind-uwnd-250_lon_mean', 419),
#   ('nmme0-prate-56w__ccsm30', 400),
#   ('icec-2010-1_lag_1', 388),
#   ('contest-wind-h10-14d__wind-hgt-10_lon_mean', 384),
#   ('contest-wind-uwnd-925-14d__wind-uwnd-925', 382),
#   ('contest-wind-h100-14d__wind-hgt-100_climateregions__climateregion_mean',
#    379),
#   ('sst-2010-2', 372),
#   ('contest-wind-h100-14d__wind-hgt-100_lat_mean', 355),
#   ('contest-slp-14d__slp_lag_2', 350),
#   ('nmme0-prate-34w__cancm30', 349),
#   ('contest-wind-h100-14d__wind-hgt-100_lag_1', 342),
#   ('wind-hgt-10-2010-2_lag_1', 342),
#   ('contest-rhum-sig995-14d__rhum', 340),
#   ('nmme0-prate-34w__gfdl0', 338),
#   ('contest-pres-sfc-gauss-14d__pres_lat_mean', 327),
#   ('contest-wind-h100-14d__wind-hgt-100_ewa', 327),
#   ('contest-wind-h500-14d__wind-hgt-500_lag_2', 320),
#   ('contest-wind-h100-14d__wind-hgt-100_lag_2', 317),
#   ('contest-rhum-sig995-14d__rhum_lat_mean', 315),
#   ('contest-wind-h850-14d__wind-hgt-850_lat_mean', 304),
#   ('wind-hgt-10-2010-2', 298),
#   ('nmme0-prate-34w__ccsm30', 294),
#   ('contest-pevpr-sfc-gauss-14d__pevpr_ewa', 291),
#   ('contest-slp-14d__slp_climateregions__climateregion_mean', 288),
#   ('contest-wind-vwnd-925-14d__wind-vwnd-925_rolling_mean', 286),
#   ('icec-2010-1', 283),
#   ('contest-slp-14d__slp_lag_1', 273),
#   ('contest-prwtr-eatm-14d__prwtr_lon_mean', 270),
#   ('wind-uwnd-250-2010-3_lag_1', 268),
#   ('contest-wind-h850-14d__wind-hgt-850_lag_1', 261),
#   ('sst-2010-2_lag_1', 253),
#   ('nmme-prate-34w__gfdlflorb', 241),
#   ('contest-wind-h100-14d__wind-hgt-100_lon_mean', 241),
#   ('contest-wind-h10-14d__wind-hgt-10_climateregions__climateregion_mean',
#    239),
#   ('nmme-prate-56w__cancm4', 237),
#   ('nmme0-prate-34w__cancm40', 234),
#   ('wind-vwnd-250-2010-13', 231),
#   ('wind-uwnd-250-2010-4_lag_1', 231),
#   ('contest-slp-14d__slp_ewa', 230),
#   ('contest-pres-sfc-gauss-14d__pres_climateregions__climateregion_mean', 229),
#   ('wind-uwnd-250-2010-3', 228),
#   ('wind-uwnd-925-2010-3', 226),
#   ('contest-wind-uwnd-250-14d__wind-uwnd-250', 220),
#   ('contest-wind-vwnd-925-14d__wind-vwnd-925_lat_mean', 219),
#   ('contest-pevpr-sfc-gauss-14d__pevpr_lag_2', 218),
#   ('contest-pres-sfc-gauss-14d__pres_lon_mean', 216),
#   ('wind-vwnd-925-2010-7_lag_1', 214),
#   ('contest-wind-h10-14d__wind-hgt-10', 212),
#   ('nmme-prate-56w__ccsm3', 210),
#   ('wind-uwnd-250-2010-4', 205),
#   ('wind-vwnd-250-2010-11', 204),
#   ('wind-hgt-10-2010-1', 203),
#   ('icec-2010-4_lag_1', 198),
#   ('wind-hgt-10-2010-1_lag_1', 197),
#   ('nmme-prate-34w__ccsm3', 195),
#   ('nmme-prate-56w__nasa', 192),
#   ('sst-2010-4_lag_1', 191),
#   ('contest-precip-14d__precip_lat_mean', 191),
#   ('contest-wind-uwnd-250-14d__wind-uwnd-250_lat_mean', 189),
#   ('contest-wind-vwnd-925-14d__wind-vwnd-925_lon_mean', 188),
#   ('contest-pevpr-sfc-gauss-14d__pevpr_lon_mean', 176),
#   ('contest-wind-h850-14d__wind-hgt-850_ewa', 176),
#   ('wind-hgt-10-2010-5', 175),
#   ('nmme-prate-34w__cfsv2', 174),
#   ('nmme0-prate-56w__cancm40', 173),
#   ('contest-wind-vwnd-250-14d__wind-vwnd-250_lon_mean', 171),
#   ('contest-wind-uwnd-925-14d__wind-uwnd-925_lat_mean', 168),
#   ('contest-wind-h10-14d__wind-hgt-10_lag_2', 165),
#   ('sst-2010-9', 164),
#   ('nmme-prate-34w__ccsm4', 162),
#   ('sst-2010-4', 162),
#   ('contest-wind-h10-14d__wind-hgt-10_lat_mean', 159),
#   ('contest-wind-vwnd-250-14d__wind-vwnd-250', 157),
#   ('wind-vwnd-250-2010-4', 156),
#   ('nmme0-prate-56w__cancm30', 155),
#   ('wind-uwnd-250-2010-18', 155),
#   ('nmme-prate-34w__cancm3', 154),
#   ('sst-2010-8', 154),
#   ('icec-2010-4', 153),
#   ('nmme-prate-34w__nasa', 152),
#   ('wind-vwnd-925-2010-7', 150),
#   ('contest-wind-vwnd-925-14d__wind-vwnd-925_lag_2', 146),
#   ('contest-wind-uwnd-925-14d__wind-uwnd-925_rolling_mean', 146),
#   ('sst-2010-8_lag_1', 142),
#   ('contest-precip-14d__precip_lon_mean', 138),
#   ('icec-2010-8', 137),
#   ('nmme0-prate-56w__cfsv20', 136),
#   ('nmme-prate-56w__gfdlflora', 136),
#   ('nmme-prate-56w__nmmemean', 135),
#   ('nmme-prate-34w__gfdlflora', 134),
#   ('contest-wind-uwnd-925-14d__wind-uwnd-925_lon_mean', 134),
#   ('wind-hgt-100-2010-2_lag_1', 133),
#   ('nmme0-prate-34w__gfdlflorb0', 129),
#   ('nmme-prate-34w__cancm4', 127),
#   ('icec-2010-7_lag_1', 127),
#   ('contest-wind-h10-14d__wind-hgt-10_rolling_mean', 127),
#   ('wind-vwnd-925-2010-6', 126),
#   ('wind-hgt-100-2010-7', 122),
#   ('icec-2010-7', 121),
#   ('wind-hgt-100-2010-7_lag_1', 121),
#   ('nmme0-prate-56w__gfdlflorb0', 120),
#   ('wind-vwnd-250-2010-4_lag_1', 120),
#   ('wind-hgt-100-2010-2', 119),
#   ('nmme0-prate-34w__nmme0mean', 118),
#   ('wind-vwnd-250-2010-13_lag_1', 118),
#   ('wind-uwnd-925-2010-3_lag_1', 118),
#   ('nmme-prate-56w__cancm3', 114),
#   ('nmme-prate-56w__cfsv2', 111),
#   ('sst-2010-9_lag_1', 111),
#   ('sst-2010-10', 110),
#   ('contest-wind-uwnd-250-14d__wind-uwnd-250_lag_2', 109),
#   ('wind-uwnd-250-2010-7_lag_1', 109),
#   ('contest-precip-14d__precip_lag_2', 106),
#   ('wind-hgt-10-2010-5_lag_1', 106),
#   ('contest-wind-uwnd-250-14d__wind-uwnd-250_rolling_mean', 106),
#   ('nmme0-prate-56w__gfdlflora0', 105),
#   ('wind-uwnd-250-2010-16', 105),
#   ('wind-hgt-850-2010-1', 105),
#   ('nmme0-prate-34w__cfsv20', 104),
#   ('wind-uwnd-925-2010-14', 104),
#   ('nmme0-prate-56w__gfdl0', 103),
#   ('contest-precip-14d__precip_rolling_mean', 103),
#   ('contest-wind-h850-14d__wind-hgt-850_lon_mean', 101),
#   ('nmme0-prate-56w__ccsm40', 99),
#   ('wind-uwnd-250-2010-7', 99),
#   ('contest-rhum-sig995-14d__rhum_lon_mean', 99),
#   ('contest-slp-14d__slp_lat_mean', 99),
#   ('nmme0-prate-56w__nasa0', 98),
#   ('sst-2010-10_lag_1', 98),
#   ('wind-hgt-100-2010-9_lag_1', 96),
#   ('wind-vwnd-250-2010-1_lag_1', 94),
#   ('wind-vwnd-250-2010-18', 93),
#   ('wind-uwnd-925-2010-15_lag_1', 93),
#   ('nmme0-prate-56w__nmme0mean', 92),
#   ('wind-hgt-10-2010-9_lag_1', 91),
#   ('contest-wind-uwnd-250-14d__wind-uwnd-250_climateregions__climateregion_mean',
#    91),
#   ('contest-wind-vwnd-925-14d__wind-vwnd-925_ewa', 90),
#   ('contest-wind-vwnd-925-14d__wind-vwnd-925_climateregions__climateregion_mean',
#    88),
#   ('nmme0-prate-34w__ccsm40', 87),
#   ('nmme0-prate-34w__gfdlflora0', 86),
#   ('contest-wind-vwnd-250-14d__wind-vwnd-250_lag_2', 86),
#   ('wind-hgt-500-2010-3_lag_1', 86),
#   ('contest-wind-h10-14d__wind-hgt-10_lag_1', 85),
#   ('contest-wind-h850-14d__wind-hgt-850_climateregions__climateregion_mean',
#    85),
#   ('contest-rhum-sig995-14d__rhum_rolling_mean', 85),
#   ('nmme-prate-56w__gfdlflorb', 83),
#   ('contest-wind-h850-14d__wind-hgt-850_lag_2', 83),
#   ('wind-vwnd-925-2010-18', 82),
#   ('wind-uwnd-250-2010-15_lag_1', 82),
#   ('contest-rhum-sig995-14d__rhum_climateregions__climateregion_mean', 82),
#   ('contest-wind-vwnd-925-14d__wind-vwnd-925_lag_1', 81),
#   ('contest-wind-h10-14d__wind-hgt-10_ewa', 81),
#   ('contest-wind-h850-14d__wind-hgt-850_rolling_mean', 79),
#   ('contest-wind-uwnd-250-14d__wind-uwnd-250_ewa', 78),
#   ('wind-hgt-10-2010-9', 77),
#   ('sst-2010-5', 76),
#   ('wind-vwnd-250-2010-18_lag_1', 76),
#   ('wind-hgt-850-2010-7_lag_1', 74),
#   ('wind-vwnd-925-2010-14_lag_1', 74),
#   ('nmme0-prate-34w__nasa0', 73),
#   ('contest-wind-uwnd-925-14d__wind-uwnd-925_lag_1', 73),
#   ('wind-vwnd-250-2010-9_lag_1', 73),
#   ('wind-uwnd-925-2010-19', 72),
#   ('wind-vwnd-925-2010-15', 72),
#   ('wind-hgt-10-2010-3', 71),
#   ('wind-uwnd-250-2010-16_lag_1', 71),
#   ('contest-wind-uwnd-250-14d__wind-uwnd-250_lag_1', 70),
#   ('contest-wind-vwnd-250-14d__wind-vwnd-250_lat_mean', 69),
#   ('sst-2010-7_lag_1', 68),
#   ('wind-hgt-850-2010-9_lag_1', 67),
#   ('sst-2010-5_lag_1', 67),
#   ('icec-2010-2_lag_1', 67),
#   ('wind-uwnd-925-2010-6_lag_1', 67),
#   ('wind-hgt-10-2010-4_lag_1', 67),
#   ('wind-hgt-500-2010-3', 66),
#   ('wind-hgt-100-2010-8', 66),
#   ('sst-2010-6_lag_1', 66),
#   ('wind-hgt-500-2010-7_lag_1', 66),
#   ('wind-vwnd-925-2010-18_lag_1', 66),
#   ('nmme-prate-34w__nmmemean', 65),
#   ('wind-hgt-500-2010-7', 65),
#   ('icec-2010-9', 65),
#   ('wind-uwnd-250-2010-18_lag_1', 65),
#   ('wind-uwnd-250-2010-9', 64),
#   ('wind-hgt-850-2010-9', 64),
#   ('wind-uwnd-925-2010-19_lag_1', 64),
#   ('wind-vwnd-250-2010-3', 63),
#   ('wind-uwnd-250-2010-15', 63),
#   ('icec-2010-8_lag_1', 63),
#   ('contest-wind-vwnd-250-14d__wind-vwnd-250_rolling_mean', 63),
#   ('wind-hgt-100-2010-3', 62),
#   ('contest-precip-14d__precip_lag_1', 61),
#   ('wind-uwnd-250-2010-11_lag_1', 61),
#   ('wind-uwnd-925-2010-15', 60),
#   ('wind-vwnd-925-2010-8', 60),
#   ('contest-precip-14d__precip_ewa', 60),
#   ('wind-uwnd-250-2010-20_lag_1', 59),
#   ('sst-2010-6', 58),
#   ('sst-2010-7', 58),
#   ('wind-vwnd-925-2010-14', 58),
#   ('icec-2010-9_lag_1', 58),
#   ('wind-hgt-100-2010-9', 57),
#   ('wind-hgt-10-2010-3_lag_1', 57),
#   ('wind-vwnd-925-2010-16_lag_1', 57),
#   ('contest-wind-uwnd-925-14d__wind-uwnd-925_ewa', 57),
#   ('wind-hgt-500-2010-4', 56),
#   ('wind-uwnd-925-2010-10', 56),
#   ('wind-hgt-100-2010-5', 56),
#   ('wind-uwnd-925-2010-12', 54),
#   ('wind-uwnd-925-2010-17', 54),
#   ('wind-hgt-500-2010-4_lag_1', 54),
#   ('wind-uwnd-925-2010-12_lag_1', 54),
#   ('wind-uwnd-925-2010-13_lag_1', 53),
#   ('wind-vwnd-250-2010-1', 52),
#   ('wind-hgt-500-2010-9', 52),
#   ('wind-uwnd-925-2010-6', 52),
#   ('contest-wind-vwnd-250-14d__wind-vwnd-250_lag_1', 52),
#   ('icec-2010-6_lag_1', 52),
#   ('contest-wind-vwnd-250-14d__wind-vwnd-250_ewa', 52),
#   ('wind-vwnd-250-2010-9', 51),
#   ('sst-2010-3', 51),
#   ('wind-uwnd-925-2010-4', 51),
#   ('wind-vwnd-250-2010-19_lag_1', 51),
#   ('wind-hgt-500-2010-1', 50),
#   ('wind-uwnd-925-2010-5_lag_1', 50),
#   ('wind-vwnd-925-2010-8_lag_1', 50),
#   ('wind-uwnd-925-2010-7', 49),
#   ('wind-vwnd-925-2010-16', 49),
#   ('wind-vwnd-925-2010-2_lag_1', 49),
#   ('wind-vwnd-250-2010-5', 48),
#   ('wind-uwnd-925-2010-13', 48),
#   ('wind-uwnd-925-2010-8_lag_1', 48),
#   ('wind-vwnd-925-2010-3_lag_1', 47),
#   ('wind-vwnd-925-2010-11_lag_1', 47),
#   ('wind-vwnd-925-2010-15_lag_1', 47),
#   ('wind-uwnd-250-2010-20', 46),
#   ('wind-hgt-850-2010-7', 46),
#   ('icec-2010-3', 46),
#   ('icec-2010-6', 46),
#   ('wind-vwnd-925-2010-6_lag_1', 46),
#   ('wind-vwnd-925-2010-3', 45),
#   ('contest-wind-uwnd-925-14d__wind-uwnd-925_lag_2', 45),
#   ('wind-uwnd-925-2010-17_lag_1', 45),
#   ('wind-hgt-850-2010-5', 44),
#   ('wind-uwnd-250-2010-1_lag_1', 44),
#   ('wind-uwnd-925-2010-14_lag_1', 44),
#   ('wind-vwnd-250-2010-14', 43),
#   ('contest-rhum-sig995-14d__rhum_lag_1', 43),
#   ('wind-vwnd-250-2010-5_lag_1', 43),
#   ('wind-hgt-500-2010-6_lag_1', 43),
#   ('icec-2010-10_lag_1', 43),
#   ('wind-vwnd-250-2010-19', 42),
#   ('wind-hgt-500-2010-8', 42),
#   ('icec-2010-2', 42),
#   ('wind-vwnd-925-2010-2', 42),
#   ('wind-vwnd-250-2010-15_lag_1', 42),
#   ('wind-vwnd-925-2010-13_lag_1', 42),
#   ('contest-wind-h10-14d__wind-hgt-10_rolling_std', 42),
#   ('wind-hgt-10-2010-4', 41),
#   ('wind-vwnd-925-2010-13', 41),
#   ('wind-uwnd-250-2010-5_lag_1', 41),
#   ('contest-wind-h500-14d__wind-hgt-500_rolling_std', 41),
#   ('wind-vwnd-250-2010-16', 40),
#   ('wind-vwnd-925-2010-1', 40),
#   ('wind-vwnd-925-2010-11', 40),
#   ('wind-vwnd-250-2010-8_lag_1', 40),
#   ('wind-uwnd-250-2010-14', 39),
#   ('wind-uwnd-250-2010-10_lag_1', 39),
#   ('sst-2010-3_lag_1', 39),
#   ('wind-uwnd-250-2010-5', 38),
#   ('wind-uwnd-925-2010-18', 38),
#   ('wind-vwnd-925-2010-17', 38),
#   ('wind-uwnd-250-2010-13_lag_1', 38),
#   ('wind-hgt-850-2010-1_lag_1', 38),
#   ('wind-uwnd-925-2010-11_lag_1', 38),
#   ('wind-uwnd-925-2010-4_lag_1', 37),
#   ('wind-uwnd-925-2010-7_lag_1', 37),
#   ('wind-hgt-100-2010-8_lag_1', 37),
#   ('wind-vwnd-250-2010-8', 36),
#   ('wind-uwnd-250-2010-11', 36),
#   ('wind-vwnd-250-2010-3_lag_1', 36),
#   ('wind-vwnd-250-2010-14_lag_1', 36),
#   ('contest-wind-uwnd-925-14d__wind-uwnd-925_climateregions__climateregion_mean',
#    36),
#   ('nmme-prate-56w__ccsm4', 35),
#   ('icec-2010-10', 35),
#   ('wind-vwnd-925-2010-19', 35),
#   ('wind-hgt-850-2010-10_lag_1', 35),
#   ('wind-hgt-10-2010-7_lag_1', 35),
#   ('wind-uwnd-250-2010-6', 34),
#   ('wind-uwnd-925-2010-8', 34),
#   ('wind-hgt-100-2010-4_lag_1', 34),
#   ('contest-wind-vwnd-250-14d__wind-vwnd-250_climateregions__climateregion_mean',
#    34),
#   ('contest-wind-h100-14d__wind-hgt-100_rolling_std', 34),
#   ('wind-uwnd-250-2010-17', 33),
#   ('wind-uwnd-925-2010-2', 33),
#   ('wind-vwnd-925-2010-4', 33),
#   ('wind-uwnd-250-2010-8_lag_1', 33),
#   ('wind-uwnd-250-2010-14_lag_1', 33),
#   ('wind-hgt-500-2010-1_lag_1', 33),
#   ('wind-uwnd-925-2010-20_lag_1', 33),
#   ('wind-uwnd-250-2010-10', 32),
#   ('mjo1d__amplitude', 32),
#   ('wind-hgt-850-2010-10', 32),
#   ('wind-hgt-500-2010-5', 32),
#   ('wind-hgt-100-2010-1_lag_1', 32),
#   ('wind-hgt-100-2010-3_lag_1', 32),
#   ('wind-vwnd-925-2010-12_lag_1', 32),
#   ('contest-precip-14d__precip_climateregions__climateregion_mean', 32),
#   ('wind-vwnd-250-2010-10', 31),
#   ('contest-rhum-sig995-14d__rhum_ewa', 31),
#   ('wind-hgt-850-2010-4', 30),
#   ('wind-vwnd-250-2010-17_lag_1', 30),
#   ('wind-uwnd-250-2010-2_lag_1', 30),
#   ('wind-uwnd-250-2010-9_lag_1', 30),
#   ('wind-uwnd-925-2010-9', 29),
#   ('wind-hgt-100-2010-4', 29),
#   ('wind-uwnd-250-2010-6_lag_1', 29),
#   ('wind-hgt-100-2010-5_lag_1', 29),
#   ('wind-vwnd-925-2010-17_lag_1', 29),
#   ('wind-vwnd-250-2010-2', 28),
#   ('wind-hgt-850-2010-8', 28),
#   ('wind-vwnd-925-2010-10', 28),
#   ('wind-uwnd-250-2010-17_lag_1', 28),
#   ('wind-hgt-10-2010-6_lag_1', 28),
#   ('wind-vwnd-925-2010-1_lag_1', 28),
#   ('wind-vwnd-925-2010-4_lag_1', 28),
#   ('wind-hgt-10-2010-10', 27),
#   ('wind-hgt-100-2010-1', 27),
#   ('wind-vwnd-250-2010-16_lag_1', 27),
#   ('wind-uwnd-925-2010-10_lag_1', 27),
#   ('wind-vwnd-925-2010-10_lag_1', 27),
#   ('wind-uwnd-250-2010-13', 26),
#   ('wind-uwnd-250-2010-19', 26),
#   ('icec-2010-5', 26),
#   ('wind-hgt-10-2010-7', 26),
#   ('contest-rhum-sig995-14d__rhum_lag_2', 26),
#   ('wind-vwnd-250-2010-2_lag_1', 26),
#   ('wind-hgt-850-2010-8_lag_1', 26),
#   ('wind-uwnd-250-2010-1', 25),
#   ('wind-uwnd-250-2010-8', 25),
#   ('wind-uwnd-925-2010-11', 25),
#   ('wind-uwnd-925-2010-20', 25),
#   ('wind-uwnd-925-2010-9_lag_1', 25),
#   ('wind-uwnd-250-2010-2', 24),
#   ('mjo1d__phase', 24),
#   ('wind-vwnd-925-2010-12', 24),
#   ('wind-vwnd-925-2010-20', 24),
#   ('wind-hgt-500-2010-5_lag_1', 24),
#   ('icec-2010-5_lag_1', 24),
#   ('wind-vwnd-925-2010-19_lag_1', 24),
#   ('wind-uwnd-250-2010-12', 23),
#   ('wind-hgt-850-2010-6', 23),
#   ('wind-hgt-500-2010-10_lag_1', 23),
#   ('wind-uwnd-925-2010-16_lag_1', 23),
#   ('wind-hgt-10-2010-10_lag_1', 23),
#   ('wind-vwnd-250-2010-17', 22),
#   ('wind-vwnd-925-2010-5', 22),
#   ('wind-vwnd-250-2010-6_lag_1', 22),
#   ('wind-uwnd-250-2010-12_lag_1', 22),
#   ('wind-hgt-850-2010-5_lag_1', 22),
#   ('icec-2010-3_lag_1', 22),
#   ('wind-uwnd-925-2010-2_lag_1', 22),
#   ('wind-hgt-10-2010-8_lag_1', 22),
#   ('wind-hgt-100-2010-10_lag_1', 22),
#   ('wind-vwnd-250-2010-7', 21),
#   ('wind-uwnd-925-2010-1', 21),
#   ('wind-hgt-500-2010-8_lag_1', 21),
#   ('wind-uwnd-925-2010-1_lag_1', 21),
#   ('wind-hgt-850-2010-3', 20),
#   ('wind-hgt-10-2010-8', 20),
#   ('wind-hgt-850-2010-6_lag_1', 20),
#   ('wind-hgt-500-2010-9_lag_1', 20),
#   ('wind-vwnd-250-2010-6', 19),
#   ('wind-vwnd-250-2010-20', 19),
#   ('wind-hgt-500-2010-2', 19),
#   ('wind-hgt-100-2010-10', 19),
#   ('wind-hgt-850-2010-4_lag_1', 19),
#   ('wind-uwnd-925-2010-18_lag_1', 19),
#   ('wind-vwnd-925-2010-20_lag_1', 19),
#   ('wind-uwnd-925-2010-5', 18),
#   ('wind-vwnd-250-2010-10_lag_1', 18),
#   ('wind-vwnd-250-2010-15', 17),
#   ('wind-hgt-500-2010-6', 17),
#   ('wind-uwnd-250-2010-19_lag_1', 17),
#   ('wind-vwnd-925-2010-9_lag_1', 17),
#   ('wind-vwnd-250-2010-12', 16),
#   ('wind-hgt-10-2010-6', 16),
#   ('wind-vwnd-250-2010-7_lag_1', 16),
#   ('wind-vwnd-250-2010-20_lag_1', 16),
#   ('wind-hgt-850-2010-2', 15),
#   ('wind-hgt-100-2010-6', 15),
#   ('wind-vwnd-250-2010-12_lag_1', 15),
#   ('wind-hgt-500-2010-10', 14),
#   ('contest-pevpr-sfc-gauss-14d__pevpr_rolling_std', 14),
#   ('wind-vwnd-925-2010-9', 13),
#   ('wind-hgt-850-2010-3_lag_1', 13),
#   ('wind-hgt-500-2010-2_lag_1', 13),
#   ('wind-hgt-850-2010-2_lag_1', 11),
#   ('wind-vwnd-925-2010-5_lag_1', 11),
#   ('contest-wind-uwnd-250-14d__wind-uwnd-250_rolling_std', 11),
#   ('wind-uwnd-925-2010-16', 10),
#   ('contest-wind-vwnd-250-14d__wind-vwnd-250_rolling_std', 10),
#   ('contest-wind-vwnd-925-14d__wind-vwnd-925_rolling_std', 9),
#   ('wind-hgt-100-2010-6_lag_1', 8),
#   ('contest-wind-uwnd-925-14d__wind-uwnd-925_rolling_std', 7),
#   ('contest-rhum-sig995-14d__rhum_rolling_std', 6),
#   ('contest-prwtr-eatm-14d__prwtr_rolling_std', 6),
#   ('contest-slp-14d__slp_rolling_std', 5),
#   ('contest-pres-sfc-gauss-14d__pres_rolling_std', 2),
#   ('contest-wind-h850-14d__wind-hgt-850_rolling_std', 2),
#   ('contest-precip-14d__precip_rolling_std', 1)],
#  457)

# %%
check = \
{'colsample_bytree': 0.85,
 'max_depth': 10,
 'min_split_gain': 0.001,
 'num_leaves': 21.46,
 'reg_alpha': 2.08,
 'reg_lambda': 0.1,
 'subsample': 0.85}

# %%
with open("Params_tunning/dict_8.pickle".format(index), "wb") as file:
    check = pickle.load(file)

# %%
lgb = lightgbm.Booster(model_file='Model/model_4.txt')

# %%
lgb.feature_importance_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [76], line 1
# ----> 1 lgb.feature_importance_
#
# AttributeError: 'LGBMRegressor' object has no attribute 'feature_importance_'

# %%
lgb.feature_name()
# Out:
# ['lat',
#  'lon',
#  'contest-pevpr-sfc-gauss-14d__pevpr',
#  'contest-wind-h10-14d__wind-hgt-10',
#  'contest-rhum-sig995-14d__rhum',
#  'nmme-prate-34w__cancm3',
#  'nmme-prate-34w__cancm4',
#  'nmme-prate-34w__ccsm3',
#  'nmme-prate-34w__ccsm4',
#  'nmme-prate-34w__cfsv2',
#  'nmme-prate-34w__gfdl',
#  'nmme-prate-34w__gfdlflora',
#  'nmme-prate-34w__gfdlflorb',
#  'nmme-prate-34w__nasa',
#  'nmme-prate-34w__nmmemean',
#  'contest-wind-h100-14d__wind-hgt-100',
#  'nmme0-prate-56w__cancm30',
#  'nmme0-prate-56w__cancm40',
#  'nmme0-prate-56w__ccsm30',
#  'nmme0-prate-56w__ccsm40',
#  'nmme0-prate-56w__cfsv20',
#  'nmme0-prate-56w__gfdlflora0',
#  'nmme0-prate-56w__gfdlflorb0',
#  'nmme0-prate-56w__gfdl0',
#  'nmme0-prate-56w__nasa0',
#  'nmme0-prate-56w__nmme0mean',
#  'nmme0-prate-34w__cancm30',
#  'nmme0-prate-34w__cancm40',
#  'nmme0-prate-34w__ccsm30',
#  'nmme0-prate-34w__ccsm40',
#  'nmme0-prate-34w__cfsv20',
#  'nmme0-prate-34w__gfdlflora0',
#  'nmme0-prate-34w__gfdlflorb0',
#  'nmme0-prate-34w__gfdl0',
#  'nmme0-prate-34w__nasa0',
#  'nmme0-prate-34w__nmme0mean',
#  'contest-slp-14d__slp',
#  'contest-wind-vwnd-925-14d__wind-vwnd-925',
#  'nmme-prate-56w__cancm3',
#  'nmme-prate-56w__cancm4',
#  'nmme-prate-56w__ccsm3',
#  'nmme-prate-56w__ccsm4',
#  'nmme-prate-56w__cfsv2',
#  'nmme-prate-56w__gfdl',
#  'nmme-prate-56w__gfdlflora',
#  'nmme-prate-56w__gfdlflorb',
#  'nmme-prate-56w__nasa',
#  'nmme-prate-56w__nmmemean',
#  'contest-pres-sfc-gauss-14d__pres',
#  'contest-wind-uwnd-250-14d__wind-uwnd-250',
#  'contest-prwtr-eatm-14d__prwtr',
#  'contest-wind-vwnd-250-14d__wind-vwnd-250',
#  'wind-uwnd-925-2010-3',
#  'wind-uwnd-925-2010-4',
#  'wind-uwnd-925-2010-5',
#  'wind-uwnd-925-2010-6',
#  'wind-uwnd-925-2010-7',
#  'wind-uwnd-925-2010-8',
#  'wind-uwnd-925-2010-9',
#  'wind-uwnd-925-2010-10',
#  'wind-uwnd-925-2010-11',
#  'wind-uwnd-925-2010-12',
#  'wind-uwnd-925-2010-13',
#  'wind-uwnd-925-2010-14',
#  'wind-uwnd-925-2010-15',
#  'wind-uwnd-925-2010-16',
#  'wind-uwnd-925-2010-17',
#  'wind-uwnd-925-2010-18',
#  'wind-uwnd-925-2010-19',
#  'wind-uwnd-925-2010-20',
#  'wind-hgt-10-2010-1',
#  'wind-hgt-10-2010-2',
#  'wind-hgt-10-2010-3',
#  'wind-hgt-10-2010-4',
#  'wind-hgt-10-2010-5',
#  'wind-hgt-10-2010-6',
#  'wind-hgt-10-2010-7',
#  'wind-hgt-10-2010-8',
#  'wind-hgt-10-2010-9',
#  'wind-hgt-10-2010-10',
#  'wind-hgt-100-2010-1',
#  'wind-hgt-100-2010-2',
#  'wind-hgt-100-2010-3',
#  'wind-hgt-100-2010-4',
#  'wind-hgt-100-2010-5',
#  'wind-hgt-100-2010-6',
#  'wind-hgt-100-2010-7',
#  'wind-hgt-100-2010-8',
#  'wind-hgt-100-2010-9',
#  'wind-hgt-100-2010-10',
#  'wind-vwnd-925-2010-1',
#  'wind-vwnd-925-2010-2',
#  'wind-vwnd-925-2010-3',
#  'wind-vwnd-925-2010-4',
#  'wind-vwnd-925-2010-5',
#  'wind-vwnd-925-2010-6',
#  'wind-vwnd-925-2010-7',
#  'wind-vwnd-925-2010-8',
#  'wind-vwnd-925-2010-9',
#  'wind-vwnd-925-2010-10',
#  'wind-vwnd-925-2010-11',
#  'wind-vwnd-925-2010-12',
#  'wind-vwnd-925-2010-13',
#  'wind-vwnd-925-2010-14',
#  'wind-vwnd-925-2010-15',
#  'wind-vwnd-925-2010-16',
#  'wind-vwnd-925-2010-17',
#  'wind-vwnd-925-2010-18',
#  'wind-vwnd-925-2010-19',
#  'wind-vwnd-925-2010-20',
#  'idx']

# %%
a = pd.DataFrame(data=np.stack((lgb.feature_name(), lgb.feature_importance().tolist()), axis=1), columns=['feature_name', 'score'])
a['score'] = a['score'].astype('int64')
a.sort_values(by=['score'], ascending=False).head(30)
# Out:
#                                  feature_name  score
# 202                                       idx  77689
# 55        contest-wind-h500-14d__wind-hgt-500  18474
# 50              contest-prwtr-eatm-14d__prwtr  15279
# 36                       contest-slp-14d__slp  13168
# 15        contest-wind-h100-14d__wind-hgt-100  12305
# 2          contest-pevpr-sfc-gauss-14d__pevpr  11419
# 48           contest-pres-sfc-gauss-14d__pres   7654
# 56              climateregions__climateregion   6329
# 57                       elevation__elevation   4921
# 162                        wind-hgt-10-2010-1   4106
# 53        contest-wind-h850-14d__wind-hgt-850   1725
# 37   contest-wind-vwnd-925-14d__wind-vwnd-925   1670
# 113                                sst-2010-2   1635
# 3           contest-wind-h10-14d__wind-hgt-10   1582
# 112                                sst-2010-1   1539
# 0                                         lat   1480
# 49   contest-wind-uwnd-250-14d__wind-uwnd-250   1350
# 163                        wind-hgt-10-2010-2   1314
# 1                                         lon   1267
# 68                      wind-vwnd-250-2010-11   1263
# 54   contest-wind-uwnd-925-14d__wind-uwnd-925   1207
# 43                       nmme-prate-56w__gfdl   1145
# 188                      wind-vwnd-925-2010-7   1009
# 52                 contest-precip-14d__precip    975
# 172                       wind-hgt-100-2010-1    916
# 173                       wind-hgt-100-2010-2    895
# 81                       wind-uwnd-250-2010-4    870
# 182                      wind-vwnd-925-2010-1    855
# 120                                sst-2010-9    806
# 4               contest-rhum-sig995-14d__rhum    798

# %%
np.stack((lgb.feature_name(), lgb.feature_importance().tolist()), axis=1).shape
# Out:
# (203, 2)

# %%
dict_stat = {}
for each in range(0, 10):
    save_model = lightgbm.Booster(model_file="Model/model_{}.txt".format(each))
    dict_ = dict(zip(save_model.feature_name(), save_model.feature_importance()))
    for key, value in dict_.items():
        if key in col_test and value > 400:
            if key not in dict_stat:
                dict_stat[key] = 0
            dict_stat[key] += 1

# %%
len(dict_stat)
# Out:
# 50

# %%
dict_stat
# Out:
# {'wind-vwnd-250-2010-1': 5,
#  'wind-vwnd-250-2010-11': 10,
#  'wind-vwnd-250-2010-13': 10,
#  'wind-uwnd-250-2010-2': 8,
#  'wind-uwnd-250-2010-3': 10,
#  'wind-uwnd-250-2010-4': 10,
#  'wind-uwnd-250-2010-10': 1,
#  'wind-hgt-850-2010-1': 10,
#  'sst-2010-1': 10,
#  'sst-2010-2': 10,
#  'sst-2010-4': 1,
#  'sst-2010-5': 3,
#  'wind-hgt-500-2010-1': 10,
#  'icec-2010-1': 9,
#  'icec-2010-2': 7,
#  'icec-2010-4': 9,
#  'icec-2010-7': 7,
#  'icec-2010-8': 10,
#  'wind-uwnd-925-2010-3': 10,
#  'wind-uwnd-925-2010-14': 9,
#  'wind-uwnd-925-2010-15': 1,
#  'wind-hgt-10-2010-1': 10,
#  'wind-hgt-10-2010-2': 10,
#  'wind-hgt-10-2010-5': 4,
#  'wind-hgt-100-2010-1': 10,
#  'wind-hgt-100-2010-2': 10,
#  'wind-hgt-100-2010-9': 2,
#  'wind-vwnd-925-2010-1': 10,
#  'wind-vwnd-925-2010-3': 8,
#  'wind-vwnd-925-2010-6': 9,
#  'wind-vwnd-925-2010-7': 10,
#  'wind-uwnd-250-2010-15': 7,
#  'wind-uwnd-250-2010-16': 6,
#  'sst-2010-3': 3,
#  'sst-2010-8': 5,
#  'sst-2010-9': 9,
#  'sst-2010-10': 3,
#  'wind-uwnd-925-2010-13': 8,
#  'wind-hgt-100-2010-7': 2,
#  'wind-vwnd-925-2010-8': 7,
#  'icec-2010-3': 5,
#  'wind-vwnd-925-2010-14': 3,
#  'wind-vwnd-250-2010-4': 2,
#  'sst-2010-6': 1,
#  'wind-hgt-500-2010-8': 1,
#  'wind-hgt-100-2010-8': 1,
#  'sst-2010-7': 2,
#  'wind-hgt-500-2010-7': 1,
#  'wind-vwnd-925-2010-10': 1,
#  'wind-vwnd-925-2010-18': 1}
